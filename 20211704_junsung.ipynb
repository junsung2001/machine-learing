# %%
# !git add .
# !git commit -m "first colab file commit"
# !git push -u origin main
# Out:
# ...
# hint: You've added another git repository inside your current repository.
# hint: Clones of the outer repository will not contain the contents of
# hint: the embedded repository and will not know how to obtain it.
# hint: If you meant to add a submodule, use:
# hint:
# hint: 	git submodule add <url> machine-learing
# hint:
# hint: If you added this path by mistake, you can remove it from the
# hint: index with:
# hint:
# hint: 	git rm --cached machine-learing
# hint:
# hint: See "git help submodule" for more information.
# [main 4e69f76] first colab file commit
#  2 files changed, 2 insertions(+)
#  create mode 100644 20211704_junsung.ipynb
#  create mode 160000 machine-learing
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://github.com/junsung2001/machine-learing.git/'

# %%
# !git config --global user.email 'hanna010248@gmail.com'
# !git config --global user.name 'junsung2001'
# !git config --list
# Out:
# filter.lfs.clean=git-lfs clean -- %f
# filter.lfs.smudge=git-lfs smudge -- %f
# filter.lfs.process=git-lfs filter-process
# filter.lfs.required=true
# user.name=junsung2001
# user.email=hanna010248@gmail.com

# %%
pwd
# Out:
# '/content/drive/MyDrive/2025-1/ml/machine-learing/machine-learing'
